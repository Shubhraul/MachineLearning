# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
# We are going to use Titanic Dataset for Encoding
Titanic = pd.read_csv('../Data/Titanic.csv')
Titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
Titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
class_mapping = {
    1: '1st class',
    2: '2nd class',
    3: '3rd class'
}

Titanic['Passenger_Class'] = Titanic['Pclass'].map(class_mapping)

print(Titanic[['Pclass', 'Passenger_Class']].head())
class_mapping1 = {
    'C': 'Cherbourg',
    'Q': 'Queenstown',
    'S': 'Southampton'
}

Titanic['Embark'] = Titanic['Embarked'].map(class_mapping1)

print(Titanic[['Embarked', 'Embark']].head())
s = Titanic['Survived']
# Out:
#    Pclass Passenger_Class
# 0       3       3rd class
# 1       1       1st class
# 2       3       3rd class
# 3       1       1st class
# 4       3       3rd class
#   Embarked       Embark
# 0        S  Southampton
# 1        C    Cherbourg
# 2        S  Southampton
# 3        S  Southampton
# 4        S  Southampton

# %%
Titanic.drop(['Pclass','Ticket','Cabin','Embarked','Survived'],axis=1,inplace=True)

# %%
Titanic['Survived']=s

# %%
Titanic.rename(columns={'Sex': 'Gender'}, inplace=True)
Titanic
# Out:
#      PassengerId                                               Name  Gender  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# ...

# %%
#Titanic.to_csv('/Titanic_Dataset.csv')
